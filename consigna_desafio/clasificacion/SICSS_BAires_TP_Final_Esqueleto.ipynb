# %% [markdown]
#   <img src="https://github.com/gefero/factor_data_tuto_NLP_SICSS/blob/main/imgs/logo_final_conjunto.png?raw=true" width="80%">
#
#
# # Summer Institute in Computational Social Sciences - Buenos Aires 2026
# # Taller: Procesamiento de Lenguaje Natural y polarización
# # Trabajo final: un índice de polarización a nivel noticia
#
# ### Profesor: Germán Rosati

# %% [markdown]
# **Grupo:**
#
# **Integrantes:**
#
# ---
#
# Este es un esqueleto vacío, para ordenarse. Las secciones siguen las preguntas de la
# [consigna](https://github.com/gefero/factor_data_tuto_NLP_SICSS/blob/main/consigna_desafio/clasificacion/CONSIGNA.md), no un método: cómo resolver cada una lo deciden ustedes.
# Agreguen, saquen o reordenen secciones si su enfoque lo pide.
#
# Conviene correr esto en Colab con GPU (`Entorno de ejecución > Cambiar tipo de entorno
# de ejecución > GPU`).

# %%
# !pip install -q pysentimiento datasets

# %% [markdown]
# # 1. ¿Qué hay en estos datos?
#
# _Antes de decidir nada, miren el dataset. Qué columnas trae, cuántas noticias y comentarios hay, cómo se reparten los comentarios entre noticias, qué les llama la atención._

# %% [markdown]
# # 2. ¿Qué vamos a llamar polarización?
#
# _La decisión conceptual, antes de escribir código. En una o dos frases: qué van a considerar polarización y qué queda afuera._

# %% [markdown]
# # 3. Clasificar los comentarios
#
# _Esto ya lo hicieron en `cap2/`. No gasten acá más tiempo del necesario._

# %% [markdown]
# # 4. Del comentario a la noticia
#
# _La construcción del índice. El salto de unidad de análisis._

# %% [markdown]
# # 5. ¿Cuántos comentarios hacen falta?
#
# _El mínimo de comentarios por noticia para que el número sea creíble. "Nos pareció razonable" no es un criterio: establézcanlo con evidencia._

# %% [markdown]
# # 6. ¿Mide lo que decimos que mide?
#
# _La validación. Qué evidencia los convencería a ustedes si se la presentara otro grupo._

# %% [markdown]
# # 7. ¿Qué polariza?
#
# _El análisis sustantivo. Para esto construyeron todo lo anterior._

# %% [markdown]
# # 8. Nuestra decisión más frágil
#
# _Cuál de sus decisiones, tomada distinto, cambiaría más el resultado. Muéstrenlo, no lo supongan._

# %% [markdown]
# # Conclusiones
#
# _Lo que se llevan del trabajo._
